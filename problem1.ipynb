# %% [markdown]
# <a href="https://colab.research.google.com/github/rcschen/ntu-quantum-app/blob/main/problem1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
! pip install pennylane torch torchvision
# or for Qiskit :
! pip install qiskit qiskit-machine-learning
# or for CUDA -Q:
#! pip install cuda-quantum

# %%
import torch
print(torch.cuda.is_available()) # should print True
print(torch.cuda.get_device_name(0)) # e.g., Tesla T4
# Out:
# True
# Tesla T4

# %%
device=torch.device("cuda" if torch.cuda.is_available() else "cpu")
